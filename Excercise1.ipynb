# %%
print("first excercise LUL")
# Out:
# first excercise LUL

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import scipy.stats as sps
#
# ModuleNotFoundError: No module named 'scipy'

# %%
s1=np.random.multivariate_normal([1,1], cov = [[1,0],[0,1]], size = 200)
s2=np.random.multivariate_normal([0,0],[[1,0.8],[0.8,1.0]], size = 200)

# %%
plt.scatter(s1[:,0],s1[:,1], label = 's1', c = 'steelblue')
plt.scatter(s2[:,0],s2[:,1], label = 's2', c = 'maroon')

# %%
def perceptron (x):

    return np.heaviside(x[0]*0.2 + x[1]*0.4 - 0.7, 1)

# %%
x1 = np.arange(0, 99)
x2 = np.arange(0, 99)
grid = []
r = []
points = []
for x in x1:
    for y in x2:
        r = perceptron([x,y])
        points.append([x,y,r])

plt.scatter(points[:,0],points[:,1], c =points[:,2], cmap = 'coolwarm_r')

# why it not work?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 11
#       8         r = perceptron([x,y])
#       9         points.append([x,y,r])
# ---> 11 plt.scatter(points[:,0],points[:,1], c =points[:,2], cmap = 'coolwarm_r')
#
# TypeError: list indices must be integers or slices, not tuple
